# %%
# This is Asma's first script for CV projects
print("Hello, group!")
# Out:
# Hello, group!

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D

model = Sequential()
